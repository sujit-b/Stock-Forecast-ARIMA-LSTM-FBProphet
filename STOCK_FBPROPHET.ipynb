# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import datetime
import yfinance as yf

# %% [markdown]
# CHRW !!!

# %%
start = datetime.datetime(2020, 11, 1)
end = datetime.datetime(2023, 11,1)

df = yf.download('CHRW', start , end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df=df.reset_index()

# %%
print(df)
# Out:
#           Date       Open       High        Low      Close  Adj Close   Volume
# 0   2020-11-02  89.970001  90.040001  86.779999  87.339996  80.561020  1800200
# 1   2020-11-03  88.500000  89.599998  87.529999  89.220001  82.295097  1352300
# 2   2020-11-04  89.129997  90.760002  88.010002  88.110001  81.271248  1173400
# 3   2020-11-05  89.680000  89.930000  87.970001  88.800003  81.907692  1399200
# 4   2020-11-06  88.839996  90.970001  88.029999  90.620003  83.586433  1362100
# ..         ...        ...        ...        ...        ...        ...      ...
# 749 2023-10-25  83.559998  83.559998  81.940002  82.730003  82.111328   815100
# 750 2023-10-26  82.800003  82.930000  80.180000  81.019997  80.414108  1167600
# 751 2023-10-27  81.779999  83.239998  80.949997  81.260002  80.652321  1511300
# 752 2023-10-30  81.809998  82.300003  80.169998  80.620003  80.017105  1499000
# 753 2023-10-31  80.699997  82.220001  80.419998  81.830002  81.218056  1450000
#
# [754 rows x 7 columns]

# %%
df = df[["Date","Close"]]

# %%
df = df.rename(columns = {"Date":"ds","Close":"y"})
df.head()
# Out:
#           ds          y
# 0 2020-11-02  87.339996
# 1 2020-11-03  89.220001
# 2 2020-11-04  88.110001
# 3 2020-11-05  88.800003
# 4 2020-11-06  90.620003

# %%
from prophet import Prophet
# The Prophet class (model)
fbp = Prophet(daily_seasonality = True)
 # Fit the model
fbp.fit(df)
fut = fbp.make_future_dataframe(periods=365)
forecast = fbp.predict(fut)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph_ct9te2/r2szh9qw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph_ct9te2/hqi377b_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5503', 'data', 'file=/tmp/tmph_ct9te2/r2szh9qw.json', 'init=/tmp/tmph_ct9te2/hqi377b_.json', 'output', 'file=/tmp/tmph_ct9te2/prophet_model0w77y4z6/prophet_model-20231214010715.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:07:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:07:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
from prophet.plot import plot_plotly, plot_components_plotly
# A better plot than the simple matplotlib
plot_plotly(fbp, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# UPS !!!

# %%
start = datetime.datetime(2020, 11, 1)
end = datetime.datetime(2023, 11,1)

df1 = yf.download('UPS', start , end)
df1=df1.reset_index()

df1 = df1[["Date","Close"]]
df1 = df1.rename(columns = {"Date":"ds","Close":"y"})

# The Prophet class (model)
fbp1 = Prophet(daily_seasonality = True)
 # Fit the model
fbp1.fit(df1)
fut1 = fbp1.make_future_dataframe(periods=30)
forecast = fbp1.predict(fut1)

plot_plotly(fbp1, forecast)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph_ct9te2/ha8kmiwp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmph_ct9te2/gmridl5n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36910', 'data', 'file=/tmp/tmph_ct9te2/ha8kmiwp.json', 'init=/tmp/tmph_ct9te2/gmridl5n.json', 'output', 'file=/tmp/tmph_ct9te2/prophet_modelt8p7158u/prophet_model-20231214011926.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:19:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:19:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...
